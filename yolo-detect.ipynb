# %% [markdown]
# # Object Detection using YOLOv3
#
# We use a pre-trained YOLOv3 model trained on COCO dataset (80 types of objects).
#
# Download model files from here [https://www.kaggle.com/datasets/valentynsichkar/yolo-coco-data](https://www.kaggle.com/datasets/valentynsichkar/yolo-coco-data)
#
# Put the model files inside a `"model"` folder
#
# You can see object names inside `model/coco.names` file.

# %% [markdown]
# # Imports

# %%
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Helper functions

# %%
def imread(path):
    return cv2.imread(path)

def imwrite(img, path):
    if cv2.imwrite(path, img):
        print('Image saved to "{}"'.format(path))
    else:
        print('Failed to save image to "{}"'.format(path))

def imshow(img, figsize=(7, 7), is_bgr=True):
    if is_bgr:
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    plt.figure(figsize=figsize)
    plt.imshow(img, cmap='gray')
    plt.show()

# %% [markdown]
# # YOLO

# %%
from my_yolo import MyYolo

# %%
yolo = MyYolo('model/')

# %% [markdown]
# ## Predict from image

# %%
img = imread('1 (224).jpg')
#imshow(img)
predictions, result = yolo.predict(img)
imshow(result)

# %%
img = imread('1 (92).jpg')
#imshow(img)
predictions, result = yolo.predict(img)
imshow(result)

# %%
img = imread('1 (202).jpg')
#imshow(img)
predictions, result = yolo.predict(img)
imshow(result)

# %%
img = imread('1 (234).jpg')
#imshow(img)
predictions, result = yolo.predict(img)
imshow(result)

# %% [markdown]
# # new photos for model

# %%
img = imread('farah.jpg')
#imshow(img)
predictions, result = yolo.predict(img)
imshow(result)

# %%
img = imread('razan.jpg')
#imshow(img)
predictions, result = yolo.predict(img)
imshow(result)

# %%
img = imread('DINA (1).jpg')
#imshow(img)
predictions, result = yolo.predict(img)
imshow(result)

# %%
img = imread('m.h.jpg')
#imshow(img)
predictions, result = yolo.predict(img)
imshow(result)

# %%
predictions
# Out:
# [{'box': [759, 948, 813, 856],
#   'class_name': 'Mo. H.',
#   'confidence': 0.9995427131652832}]

# %% [markdown]
# ## Predict from web cam

# %%
yolo.predict_from_cam()

# %% [markdown]
# # How to train YOLO for custom objects?
# Watch this video [https://www.youtube.com/watch?v=hTCmL3S4Obw](https://www.youtube.com/watch?v=hTCmL3S4Obw)
